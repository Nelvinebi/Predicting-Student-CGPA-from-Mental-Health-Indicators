# %%
{
 "nbformat": 4,
 "nbformat_minor": 5,
 "metadata": {
  "kernelspec": {"display_name": "Python 3", "language": "python", "name": "python3"},
  "language_info": {"name": "python", "version": "3.9.0"}
 },
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": ["# 🧠 MindGrade\n### Predicting Student CGPA from Mental Health Indicators\n---"]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import sys, os\n",
    "sys.path.insert(0, os.path.join(os.getcwd(), 'src'))"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": ["## Phase 1 — Data Cleaning"]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "from phase1_data_cleaning import run as run_phase1\n",
    "df_clean = run_phase1()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": ["df_clean.head(10)"]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": ["## Phase 2 — Exploratory Data Analysis"]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "from phase2_eda import run as run_phase2\n",
    "run_phase2()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": ["## Phase 3 — Feature Engineering"]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "from phase3_feature_engineering import run as run_phase3\n",
    "X_train, X_test, y_train, y_test, X_res, y_res = run_phase3()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": ["## Phase 4 — Modelling & Evaluation"]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "from phase4_modelling import run as run_phase4\n",
    "run_phase4()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": ["## Phase 5 — Report Generation"]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "from phase5_reporting import run as run_phase5\n",
    "run_phase5()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "---\n",
    "**Report generated.** Open `outputs/reports/MindGrade_Report.html` in your browser."
   ]
  }
 ]
}
